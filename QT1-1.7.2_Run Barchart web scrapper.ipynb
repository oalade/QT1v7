# %%
#Fri. Apr 4, 2020
import import_ipynb, QT7
from QT7 import QT1v7
QT1v7()
# Out:
# importing Jupyter notebook from QT7.ipynb
# status update: complete
# wait 0.001 hours
# check1
# starting between 04.03.2020_11.27 and 04.03.2020_11.28
# check2
# check3b
# check3b
# loading QT1-7 Range Changers at 04.03.2020_11.27
# status update: opened webpage and logging in
# status update: successfully logged in and waiting to download range changers
# check3a
# 04.03.2020_11.31
# 04.03.2020_11.32
#
# check4
# check5b
# downloading range changers at 04.03.2020_11.31
# status update: successfully downloaded range changers
# check5a
# check5c
# 04.03.2020_11.35
# 04.03.2020_10.36
#
# check4
# check5b
# check5b
# check5b
# check5b
# check5b
# check5b
# check5b
# check5b
# check5b
# downloading range changers at 04.03.2020_11.35
# status update: successfully downloaded range changers
# check5a
# check5c
# loading QT1-7 Range Changers at 04.03.2020_11.35
# status update: opened webpage and logging in
# status update: successfully logged in and waiting to download range changers
# ...

# %%
#Mon. Apr 7, 2020
import import_ipynb, QT7
from QT7 import QT1v7
QT1v7()

# %%
#Sat. Apr 5, 2020
#test
import import_ipynb, QT7
from QT7 import QT1v7
QT1v7()
